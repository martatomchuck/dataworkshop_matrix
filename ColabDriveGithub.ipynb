# %%
from google.colab import drive

# %%
# Linking Colab with Drive (external google drive)
ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Defining home path 
HOME = ROOT + '/My Drive/Colab Notebooks'

# %%
# !mkdir -p "{HOME}"

# %%
cd {HOME}
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
ls
# Out:
# ColabDriveGithub.ipynb

# %%
GITHUB_TOKEN = 'e16d79c165ee9b0295e792e3e73ad58a9475c601'

# %%
GITHUB_URL = 'https://{0}@github.com/mtomchuck/dataworkshop_matrix.git'.format(GITHUB_TOKEN)

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'dataworkshop_matrix'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 17 (delta 6), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
ls
# Out:
# ColabDriveGithub.ipynb  dataworkshop_matrix/

# %%
cd dataworkshop_matrix/
# Out:
# /content/drive/My Drive/Colab Notebooks/dataworkshop_matrix

# %%
ls
# Out:
# LICENSE  README.md

# %%
ls
# Out:
# ColabDriveGithub.ipynb  HelloGithub.ipynb  LICENSE  README.md

# %%
# !git add HelloGithub.ipynb

# %%
# !git commit -m "Colab notebook"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@518faf1cff7d.(none)')

# %%
# !git config --global user.email "marta.tomczak.uj@gmail.com"
# !git config --global user.name "Marta"

# %%
# !git commit -m "Colab notebook"
# Out:
# [master 3fa910f] Colab notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 HelloGithub.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 831 bytes | 415.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/mtomchuck/dataworkshop_matrix.git
#    0844fe1..3fa910f  master -> master
